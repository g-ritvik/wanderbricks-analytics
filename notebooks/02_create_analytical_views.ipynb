# %% [markdown]
# ## Objective
#
# Build reusable analytical views that will be used for booking performance and marketing analysis.

# %%
# %sql
USE CATALOG wanderbricks_analytics;
USE SCHEMA analytics;

# %% [markdown]
# ## Testing booking_details view
#
# - rows in booking_details: 72247
# - rows in bookings table: 72247
# - distinct booking_id count: 72247
#
# **nulls**
# - host_id: no nulls
# - destination_name: no nulls
# - user_id: no nulls
# - property_id: no nulls
#
# **length of stays and amount**
# - No negative & 0 duration of stays
# - only one entry has negative amount
#
# *no other nulls for important columns*

# %% [markdown]
# View definition is available in `sql/booking_details.sql`.

# %%
# %sql
DESCRIBE booking_details

# %%
# %sql
SELECT *
FROM booking_details
LIMIT 10;

# %% [markdown]
# ## Testing property_marketing view
#
# - rows in property_marketing: 500k
# - rows in page_views: 500k
# - distinct view_ids: 5k

# %% [markdown]
# View definition is available in `sql/property_marketing.sql`.

# %%
# %sql
DESCRIBE property_marketing

# %%
# %sql
SELECT *
FROM property_marketing
LIMIT 10;
